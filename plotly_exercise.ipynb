# %% [markdown]
# ## Plotly Assignment
#
# **Note**: For some of you, plotly go does not display at all in Jupyter Labs. It is a known bug with plotly. If you are using Jupyter Labs for this assignment and the plots are not showing, please switch to Jupyter Notebooks or Google Collab to complete this exercise.

# %%
# import plotly graph objects
import plotly.graph_objs as go

# import pandas
import pandas as pd
import numpy as np

# %% [markdown]
# ### Task 1: Create a scatterplot with a 1000 random data points.
#
# - x-axis values should come from a normal distribution using np.random.randn(1000)
#
# - y-axis values should come from a uniform distribution over [0,1) using np.random.rand(1000)

# %%
# obtain the x and y values:
random_x = np.random.randint(1,1001,1000)
random_y = np.random.randint(1,1001,1000)

# %%
# define a data variable
data = [go.Scatter(
x= random_x,
y= random_y,
mode='markers',)]

# %%
# define the layout, include a title and axis labels
layout = go.Layout(
    title = 'Random Data Scatterplot', # Graph title
    xaxis = dict(title = 'Some random x-values'), # x-axis label
    yaxis = dict(title = 'Some random y-values'), # y-axis label
    hovermode ='closest' # handles multiple points landing on the same vertical
)

# %%
# Create a fig from the data and layout. Then plot the fig
fig = go.Figure(data=data, layout=layout)
fig.show()
# Out:
# <div>                            <div id="3199b51c-51e2-44e2-b3e4-b889bb7bb2f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3199b51c-51e2-44e2-b3e4-b889bb7bb2f2")) {                    Plotly.newPlot(                        "3199b51c-51e2-44e2-b3e4-b889bb7bb2f2",                        [{"mode":"markers","x":[411,730,927,40,906,533,925,104,197,404,776,163,29,293,677,111,46,778,109,281,176,270,455,668,490,96,192,41,949,828,457,1000,65,371,964,277,803,703,15,763,929,545,670,188,772,493,631,782,139,374,167,521,447,370,48,368,807,416,142,537,411,348,362,672,152,107,536,615,898,342,482,324,166,316,106,735,11,77,425,42,171,677,500,683,900,893,949,433,345,520,98,346,175,774,347,963,410,843,381,809,112,876,772,323,689,663,868,160,753,509,146,320,113,670,923,502,476,545,540,898,97,911,6,10,209,597,363,126,67,958,457,27,232,379,140,614,320,333,406,734,740,380,600,265,695,114,778,371,142,939,945,10,312,679,530,445,745,591,210,863,845,983,875,656,325,296,464,143,486,190,986,732,526,109,960,895,90,180,110,563,968,306,771,180,396,246,572,3,451,227,699,370,957,437,662,879,876,324,561,727,417,411,810,276,182,772,446,202,57,880,65,207,946,58,628,813,192,339,175,330,295,195,808,384,301,161,436,88,335,861,878,78,749,248,990,147,579,868,942,40,512,589,567,309,864,940,5,544,990,131,24,498,262,984,514,123,574,472,333,424,750,118,782,412,13,517,902,142,952,760,440,16,546,130,488,645,768,672,921,544,226,136,926,230,359,588,496,127,205,190,481,466,764,249,670,991,902,273,316,864,969,304,409,4,315,95,363,73,832,986,981,308,987,776,458,452,577,204,570,604,924,375,635,369,746,119,652,196,229,147,954,640,794,991,643,2,638,112,800,735,587,234,859,754,800,798,562,978,50,80,390,2,954,217,656,568,251,442,301,767,692,63,544,604,76,784,510,871,867,217,702,460,234,275,121,202,736,553,887,897,687,47,471,505,965,872,986,507,37,371,774,978,325,785,846,516,360,409,673,314,777,509,459,827,370,447,684,638,961,913,264,749,885,277,185,573,493,719,608,557,149,987,316,985,935,229,683,90,946,651,437,536,599,399,50,773,332,890,950,72,252,12,286,869,958,672,592,254,164,339,438,80,771,346,475,771,920,436,635,797,224,564,966,945,276,625,678,510,321,773,200,916,2,348,798,202,673,958,14,173,600,607,392,567,508,122,937,223,992,457,646,588,988,253,129,220,598,131,389,792,487,3,507,804,960,686,130,236,467,132,636,321,196,200,628,185,670,268,105,755,478,365,708,191,430,707,625,323,983,305,374,29,457,658,611,998,669,648,289,384,83,693,487,654,706,551,565,491,61,846,451,104,130,302,846,782,296,156,829,794,445,814,824,813,976,142,780,171,557,897,906,536,745,702,953,174,585,170,819,48,735,862,269,104,613,503,102,947,393,368,628,302,512,319,506,762,349,438,178,100,279,182,401,704,71,964,81,509,125,947,498,918,538,462,688,712,550,432,125,534,351,200,232,427,346,547,835,820,901,574,192,499,816,913,490,279,444,453,753,809,246,255,922,784,248,106,190,404,234,619,382,175,587,242,209,165,235,949,788,210,389,651,645,953,749,390,257,960,921,695,576,68,245,806,331,638,274,978,932,352,593,236,214,871,858,456,730,135,722,502,170,106,294,571,563,476,349,624,70,637,450,883,496,834,406,153,760,775,818,103,503,340,959,626,120,305,362,163,921,763,459,465,512,627,291,307,467,406,260,121,794,841,342,841,877,206,948,506,197,916,358,371,754,500,306,909,417,285,373,627,3,868,432,869,22,187,645,317,247,341,37,268,779,724,102,104,810,258,221,360,341,319,765,848,286,820,909,376,66,242,294,333,703,196,540,994,749,397,3,710,388,561,958,301,643,481,127,318,534,13,651,692,775,642,339,424,386,215,374,851,956,568,299,304,349,486,16,510,197,783,125,953,853,694,137,998,492,301,691,335,588,309,177,28,845,92,235,38,992,328,48,237,859,452,481,650,56,470,391,714,281,970,154,851,905,944,822,652,145,614,862,632,24,914,606,240,18,209,492,373,461,147,354,190,124,81,455,433,36,553,724,619, ...

# %% [markdown]
# -------------
# ### Task 2: Create a stacked bar chart with the data from the link below.
#
# **Note** that the questions appear in the index and should be used for the x-axis, while the responses appear as column labels. You will need to create more `traces`, one for each column.
#
# Stretch Task: Create a horizontal bar chart! Use this documentation [here](https://plot.ly/python/horizontal-bar-charts/) for help.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/mocksurvey.csv',index_col=0)
df
# Out:
#             Strongly Agree  Somewhat Agree  Neutral  Somewhat Disagree  \
# Question 1            0.45            0.25     0.10               0.12
# Question 2            0.12            0.07     0.48               0.18
# Question 3            0.05            0.22     0.19               0.23
#
#             Strongly Disagree
# Question 1               0.08
# Question 2               0.15
# Question 3               0.31

# %%
# create traces using a list comprehension:

# %%
# create a layout, remember to set the barmode here

# %%
# create a fig from data & layout, and plot the fig.

# %% [markdown]
# -------------
# ### Task 3: Create a histogram that plots the `length` field from dataset below. Set the range from 0 to 1, with a bin size of 0.02.

# %%
# load data
df = pd.read_csv('https://raw.githubusercontent.com/Pierian-Data/Plotly-Dashboards-with-Dash/master/Data/abalone.csv')

# %%
# create a data variable:

# %%
# add a layout

# %%
# create a fig from data & layout, and plot the fig
